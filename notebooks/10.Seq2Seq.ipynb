# %% [markdown]
# # Poetry Generation with LSTM

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense,LSTM,Embedding,Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam, SGD
import tensorflow.keras.backend as K

# %%
MAX_SEQUENCE_LENGTH=100
MAX_VOCAB_SIZE=3000
EMBEDDING_DIM=50
VALIDATION_SPLIT=0.2
BATCH_SIZE=128
EPOCHS=2000
LATENT_DIM=25

# %%
# load in the data
input_texts = []
target_texts = []
for line in open('./large_files/robert_frost.txt'):
    line = line.rstrip()
    if not line:
        continue
    input_line = '<sos> ' + line
    target_line = line + ' <eos>'
    
    input_texts.append(input_line)
    target_texts.append(target_line)

all_lines = input_texts+target_texts

# %%
for l in input_texts:
    if 'bulkhead' in l:
        print(l)
# Out:
# <sos> The bulkhead double-doors were double-locked

# %% [markdown]
# ## Tokenization

# %%
# convert the sentences (strings) into integers
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE,filters='')
tokenizer.fit_on_texts(all_lines)
input_sequences = tokenizer.texts_to_sequences(input_texts)
target_sequences = tokenizer.texts_to_sequences(target_texts)

# %%
# find max seq length
max_sequence_length_from_data = max(len(s) for s in input_sequences)
print('Max sequence length:', max_sequence_length_from_data)
# Out:
# Max sequence length: 12

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
print('Found %s unique tokens.' % len(word2idx))
# Out:
# Found 3056 unique tokens.

# %% [markdown]
# ## Padding

# %%
# pad sequences so that we get a N x T matrix
max_sequence_length = min(max_sequence_length_from_data,MAX_SEQUENCE_LENGTH)
input_sequences=pad_sequences(input_sequences,maxlen=max_sequence_length,padding='post')
target_sequences=pad_sequences(target_sequences,maxlen=max_sequence_length,padding='post')
print('Shape of data tensor:', input_sequences.shape)
# Out:
# Shape of data tensor: (1436, 12)

# %% [markdown]
# ## Load word embedding

# %%
# load in pre-trained word vectors
word2vec ={}
with open('./large_files/glove.6B/glove.6B.{}d.txt'.format(EMBEDDING_DIM)) as f:
    for line in f:
        values = line.split()
        word=values[0]
        vec = np.array(values[1:],dtype='float32')
        word2vec[word]=vec
print('Found %s word vectors.' % len(word2vec))
# Out:
# Found 400000 word vectors.

# %%
# prepare embedding matrix
num_words = min(MAX_VOCAB_SIZE, len(word2idx)+1)
embedding_matrix = np.zeros((num_words,EMBEDDING_DIM))
for word,i in word2idx.items():
    if i<MAX_VOCAB_SIZE:
        embedding_vec = word2vec.get(word)
        if embedding_vec is not None:
            embedding_matrix[i]=embedding_vec

# %% [markdown]
# If you pass in the `sparse_categorical_crossentropy` loss function into Keras it won't work when each target is a sequence.

# %%
# one-hot the targets (can't use sparse cross-entropy)
one_hot_targets = np.zeros((len(input_sequences),max_sequence_length,num_words))
for i, target_sequence in enumerate(target_sequences):
    for t,word in enumerate(target_sequence):
        if word>0:
            one_hot_targets[i,t,word]=1
one_hot_targets.shape
# Out:
# (1436, 12, 3000)

# %% [markdown]
# ## Build model

# %%
# load pre-trained word embeddings into an Embedding layer
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            #trainable=False
                           )

# %% [markdown]
# For this model we have three inputs:

# %%
# create an LSTM network with a single LSTM
input_=Input(shape=(max_sequence_length,))
# hidden state
intial_h = Input(shape=(LATENT_DIM,))
# cell state
intial_c = Input(shape=(LATENT_DIM,))

# %% [markdown]
# We want to pass in the hidden state and cell state because we want to have control over the initial states.
#
# We're going to pass in the same states during prediction.
#
# So we want there to be consistency once we have our inputs.

# %%
x=embedding_layer(input_)

# return_sequences = True , because LSTM output must be a sequence since it has to predict the rest of the sentence.
lstm=LSTM(LATENT_DIM,return_sequences=True,return_state=True)
x,_,_ = lstm(x,initial_state=[intial_h,intial_c])
dense = Dense(num_words,activation='softmax')
output=dense(x)

# %%
model=Model([input_,intial_h,intial_c],output)
model.compile(loss='categorical_crossentropy',
              optimizer = Adam(lr=0.01),
              metrics = ['accuracy'])
model.summary()
# Out:
# Model: "functional_31"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_24 (InputLayer)           [(None, 12)]         0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 12, 50)       150000      input_24[0][0]
# __________________________________________________________________________________________________
# input_25 (InputLayer)           [(None, 25)]         0
# __________________________________________________________________________________________________
# input_26 (InputLayer)           [(None, 25)]         0
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 12, 25), (No 7600        embedding_2[0][0]
#                                                                  input_25[0][0]
#                                                                  input_26[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 12, 3000)     78000       lstm_2[0][0]
# ==================================================================================================
# Total params: 235,600
# Trainable params: 235,600
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
z=np.zeros((len(input_sequences), LATENT_DIM))

# %%
r = model.fit([input_sequences, z, z],
              one_hot_targets,
              batch_size=BATCH_SIZE,
              epochs=EPOCHS,
              validation_split=VALIDATION_SPLIT)
# Out:
# Epoch 1/2000
# 9/9 [==============================] - 1s 98ms/step - loss: 5.3951 - accuracy: 0.0478 - val_loss: 5.0740 - val_accuracy: 0.0104
# Epoch 2/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.6433 - accuracy: 0.0558 - val_loss: 4.8233 - val_accuracy: 0.0833
# Epoch 3/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.3837 - accuracy: 0.0833 - val_loss: 4.9301 - val_accuracy: 0.0833
# Epoch 4/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 4.3291 - accuracy: 0.0833 - val_loss: 4.9373 - val_accuracy: 0.0833
# Epoch 5/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.2905 - accuracy: 0.0833 - val_loss: 4.9694 - val_accuracy: 0.0833
# Epoch 6/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.2526 - accuracy: 0.0833 - val_loss: 4.9461 - val_accuracy: 0.0833
# Epoch 7/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 4.2018 - accuracy: 0.0833 - val_loss: 4.9051 - val_accuracy: 0.0833
# Epoch 8/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.1438 - accuracy: 0.0833 - val_loss: 4.8722 - val_accuracy: 0.0833
# Epoch 9/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 4.0847 - accuracy: 0.0833 - val_loss: 4.8440 - val_accuracy: 0.0833
# Epoch 10/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 4.0282 - accuracy: 0.0833 - val_loss: 4.8280 - val_accuracy: 0.0833
# Epoch 11/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.9753 - accuracy: 0.0838 - val_loss: 4.8175 - val_accuracy: 0.0856
# Epoch 12/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.9214 - accuracy: 0.0936 - val_loss: 4.8124 - val_accuracy: 0.0891
# Epoch 13/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.8738 - accuracy: 0.0973 - val_loss: 4.8077 - val_accuracy: 0.0894
# Epoch 14/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.8302 - accuracy: 0.0995 - val_loss: 4.8129 - val_accuracy: 0.0874
# Epoch 15/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.7893 - accuracy: 0.1010 - val_loss: 4.8197 - val_accuracy: 0.0877
# Epoch 16/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.7540 - accuracy: 0.1034 - val_loss: 4.8337 - val_accuracy: 0.0885
# Epoch 17/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.7189 - accuracy: 0.1060 - val_loss: 4.8412 - val_accuracy: 0.0874
# Epoch 18/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.6855 - accuracy: 0.1075 - val_loss: 4.8521 - val_accuracy: 0.0877
# Epoch 19/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.6529 - accuracy: 0.1076 - val_loss: 4.8590 - val_accuracy: 0.0880
# Epoch 20/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.6208 - accuracy: 0.1079 - val_loss: 4.8700 - val_accuracy: 0.0880
# Epoch 21/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.5887 - accuracy: 0.1128 - val_loss: 4.8750 - val_accuracy: 0.0940
# Epoch 22/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.5568 - accuracy: 0.1180 - val_loss: 4.8808 - val_accuracy: 0.0920
# Epoch 23/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.5258 - accuracy: 0.1221 - val_loss: 4.8777 - val_accuracy: 0.0938
# Epoch 24/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.4930 - accuracy: 0.1242 - val_loss: 4.8766 - val_accuracy: 0.0975
# Epoch 25/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.4622 - accuracy: 0.1241 - val_loss: 4.8803 - val_accuracy: 0.0938
# Epoch 26/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.4293 - accuracy: 0.1270 - val_loss: 4.8866 - val_accuracy: 0.0955
# Epoch 27/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.3973 - accuracy: 0.1288 - val_loss: 4.8872 - val_accuracy: 0.0995
# Epoch 28/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.3639 - accuracy: 0.1340 - val_loss: 4.8935 - val_accuracy: 0.0987
# Epoch 29/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.3302 - accuracy: 0.1361 - val_loss: 4.8983 - val_accuracy: 0.0964
# Epoch 30/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.2978 - accuracy: 0.1372 - val_loss: 4.9038 - val_accuracy: 0.0992
# Epoch 31/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.2656 - accuracy: 0.1430 - val_loss: 4.9113 - val_accuracy: 0.0984
# Epoch 32/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.2322 - accuracy: 0.1482 - val_loss: 4.9191 - val_accuracy: 0.0992
# Epoch 33/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.2007 - accuracy: 0.1520 - val_loss: 4.9298 - val_accuracy: 0.0987
# Epoch 34/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.1675 - accuracy: 0.1551 - val_loss: 4.9309 - val_accuracy: 0.0984
# Epoch 35/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.1363 - accuracy: 0.1589 - val_loss: 4.9348 - val_accuracy: 0.0978
# Epoch 36/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.1051 - accuracy: 0.1613 - val_loss: 4.9485 - val_accuracy: 0.0978
# Epoch 37/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.0746 - accuracy: 0.1650 - val_loss: 4.9560 - val_accuracy: 0.0966
# Epoch 38/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 3.0443 - accuracy: 0.1674 - val_loss: 4.9622 - val_accuracy: 0.1001
# Epoch 39/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 3.0139 - accuracy: 0.1727 - val_loss: 4.9721 - val_accuracy: 0.0975
# Epoch 40/2000
# 9/9 [==============================] - 1s 72ms/step - loss: 2.9847 - accuracy: 0.1770 - val_loss: 4.9807 - val_accuracy: 0.0972
# Epoch 41/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.9561 - accuracy: 0.1786 - val_loss: 4.9934 - val_accuracy: 0.0969
# Epoch 42/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.9287 - accuracy: 0.1824 - val_loss: 5.0045 - val_accuracy: 0.0969
# Epoch 43/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.9008 - accuracy: 0.1857 - val_loss: 5.0157 - val_accuracy: 0.0955
# Epoch 44/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.8736 - accuracy: 0.1884 - val_loss: 5.0230 - val_accuracy: 0.0966
# Epoch 45/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.8475 - accuracy: 0.1913 - val_loss: 5.0330 - val_accuracy: 0.0964
# Epoch 46/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.8211 - accuracy: 0.1950 - val_loss: 5.0427 - val_accuracy: 0.0964
# Epoch 47/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.7961 - accuracy: 0.1982 - val_loss: 5.0547 - val_accuracy: 0.0946
# Epoch 48/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.7717 - accuracy: 0.2012 - val_loss: 5.0709 - val_accuracy: 0.0955
# Epoch 49/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.7476 - accuracy: 0.2047 - val_loss: 5.0741 - val_accuracy: 0.0966
# Epoch 50/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.7239 - accuracy: 0.2059 - val_loss: 5.0890 - val_accuracy: 0.0966
# Epoch 51/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.6998 - accuracy: 0.2097 - val_loss: 5.1018 - val_accuracy: 0.0938
# Epoch 52/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.6777 - accuracy: 0.2130 - val_loss: 5.1141 - val_accuracy: 0.0949
# Epoch 53/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.6555 - accuracy: 0.2145 - val_loss: 5.1252 - val_accuracy: 0.0932
# Epoch 54/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.6332 - accuracy: 0.2173 - val_loss: 5.1350 - val_accuracy: 0.0946
# Epoch 55/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.6132 - accuracy: 0.2200 - val_loss: 5.1470 - val_accuracy: 0.0938
# Epoch 56/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.5919 - accuracy: 0.2215 - val_loss: 5.1573 - val_accuracy: 0.0935
# Epoch 57/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.5731 - accuracy: 0.2239 - val_loss: 5.1699 - val_accuracy: 0.0938
# Epoch 58/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.5531 - accuracy: 0.2255 - val_loss: 5.1804 - val_accuracy: 0.0917
# Epoch 59/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.5331 - accuracy: 0.2286 - val_loss: 5.1919 - val_accuracy: 0.0938
# Epoch 60/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.5151 - accuracy: 0.2297 - val_loss: 5.2032 - val_accuracy: 0.0923
# Epoch 61/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.4961 - accuracy: 0.2339 - val_loss: 5.2138 - val_accuracy: 0.0929
# Epoch 62/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.4785 - accuracy: 0.2363 - val_loss: 5.2279 - val_accuracy: 0.0926
# Epoch 63/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.4603 - accuracy: 0.2369 - val_loss: 5.2353 - val_accuracy: 0.0935
# Epoch 64/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.4439 - accuracy: 0.2385 - val_loss: 5.2507 - val_accuracy: 0.0940
# Epoch 65/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.4263 - accuracy: 0.2409 - val_loss: 5.2608 - val_accuracy: 0.0929
# Epoch 66/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.4109 - accuracy: 0.2436 - val_loss: 5.2737 - val_accuracy: 0.0932
# Epoch 67/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.3940 - accuracy: 0.2458 - val_loss: 5.2825 - val_accuracy: 0.0914
# Epoch 68/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.3783 - accuracy: 0.2477 - val_loss: 5.2974 - val_accuracy: 0.0906
# Epoch 69/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.3634 - accuracy: 0.2492 - val_loss: 5.3061 - val_accuracy: 0.0932
# Epoch 70/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.3480 - accuracy: 0.2501 - val_loss: 5.3212 - val_accuracy: 0.0885
# Epoch 71/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.3340 - accuracy: 0.2520 - val_loss: 5.3335 - val_accuracy: 0.0891
# Epoch 72/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.3200 - accuracy: 0.2533 - val_loss: 5.3442 - val_accuracy: 0.0871
# Epoch 73/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.3051 - accuracy: 0.2562 - val_loss: 5.3522 - val_accuracy: 0.0877
# Epoch 74/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2916 - accuracy: 0.2568 - val_loss: 5.3677 - val_accuracy: 0.0842
# Epoch 75/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.2785 - accuracy: 0.2578 - val_loss: 5.3767 - val_accuracy: 0.0845
# Epoch 76/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.2643 - accuracy: 0.2591 - val_loss: 5.3913 - val_accuracy: 0.0880
# Epoch 77/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2520 - accuracy: 0.2617 - val_loss: 5.4010 - val_accuracy: 0.0859
# Epoch 78/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2391 - accuracy: 0.2628 - val_loss: 5.4100 - val_accuracy: 0.0833
# Epoch 79/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2272 - accuracy: 0.2655 - val_loss: 5.4214 - val_accuracy: 0.0848
# Epoch 80/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2150 - accuracy: 0.2664 - val_loss: 5.4329 - val_accuracy: 0.0839
# Epoch 81/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.2033 - accuracy: 0.2667 - val_loss: 5.4415 - val_accuracy: 0.0836
# Epoch 82/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.1921 - accuracy: 0.2685 - val_loss: 5.4516 - val_accuracy: 0.0851
# Epoch 83/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1805 - accuracy: 0.2710 - val_loss: 5.4630 - val_accuracy: 0.0828
# Epoch 84/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1692 - accuracy: 0.2708 - val_loss: 5.4732 - val_accuracy: 0.0845
# Epoch 85/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1587 - accuracy: 0.2731 - val_loss: 5.4849 - val_accuracy: 0.0819
# Epoch 86/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1469 - accuracy: 0.2745 - val_loss: 5.4964 - val_accuracy: 0.0830
# Epoch 87/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1364 - accuracy: 0.2756 - val_loss: 5.5034 - val_accuracy: 0.0842
# Epoch 88/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1268 - accuracy: 0.2750 - val_loss: 5.5173 - val_accuracy: 0.0807
# Epoch 89/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.1164 - accuracy: 0.2772 - val_loss: 5.5227 - val_accuracy: 0.0839
# Epoch 90/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.1069 - accuracy: 0.2781 - val_loss: 5.5332 - val_accuracy: 0.0830
# Epoch 91/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0967 - accuracy: 0.2811 - val_loss: 5.5391 - val_accuracy: 0.0807
# Epoch 92/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0865 - accuracy: 0.2814 - val_loss: 5.5556 - val_accuracy: 0.0804
# Epoch 93/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.0768 - accuracy: 0.2828 - val_loss: 5.5601 - val_accuracy: 0.0784
# Epoch 94/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.0683 - accuracy: 0.2841 - val_loss: 5.5723 - val_accuracy: 0.0784
# Epoch 95/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0580 - accuracy: 0.2858 - val_loss: 5.5813 - val_accuracy: 0.0813
# Epoch 96/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.0483 - accuracy: 0.2870 - val_loss: 5.5901 - val_accuracy: 0.0778
# Epoch 97/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0404 - accuracy: 0.2884 - val_loss: 5.5961 - val_accuracy: 0.0799
# Epoch 98/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 2.0315 - accuracy: 0.2888 - val_loss: 5.6076 - val_accuracy: 0.0767
# Epoch 99/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0215 - accuracy: 0.2911 - val_loss: 5.6163 - val_accuracy: 0.0767
# Epoch 100/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0126 - accuracy: 0.2920 - val_loss: 5.6261 - val_accuracy: 0.0787
# Epoch 101/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 2.0032 - accuracy: 0.2928 - val_loss: 5.6352 - val_accuracy: 0.0775
# Epoch 102/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9954 - accuracy: 0.2938 - val_loss: 5.6355 - val_accuracy: 0.0781
# Epoch 103/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.9867 - accuracy: 0.2954 - val_loss: 5.6517 - val_accuracy: 0.0767
# Epoch 104/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9790 - accuracy: 0.2950 - val_loss: 5.6631 - val_accuracy: 0.0755
# Epoch 105/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.9700 - accuracy: 0.2975 - val_loss: 5.6699 - val_accuracy: 0.0741
# Epoch 106/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9617 - accuracy: 0.2992 - val_loss: 5.6741 - val_accuracy: 0.0758
# Epoch 107/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9540 - accuracy: 0.2991 - val_loss: 5.6840 - val_accuracy: 0.0767
# Epoch 108/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.9454 - accuracy: 0.2997 - val_loss: 5.6966 - val_accuracy: 0.0749
# Epoch 109/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9387 - accuracy: 0.3025 - val_loss: 5.7065 - val_accuracy: 0.0758
# Epoch 110/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9318 - accuracy: 0.3030 - val_loss: 5.7168 - val_accuracy: 0.0752
# Epoch 111/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9241 - accuracy: 0.3053 - val_loss: 5.7201 - val_accuracy: 0.0738
# Epoch 112/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9159 - accuracy: 0.3062 - val_loss: 5.7254 - val_accuracy: 0.0747
# Epoch 113/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.9100 - accuracy: 0.3049 - val_loss: 5.7366 - val_accuracy: 0.0747
# Epoch 114/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.9015 - accuracy: 0.3077 - val_loss: 5.7466 - val_accuracy: 0.0738
# Epoch 115/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8951 - accuracy: 0.3072 - val_loss: 5.7523 - val_accuracy: 0.0741
# Epoch 116/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8866 - accuracy: 0.3113 - val_loss: 5.7620 - val_accuracy: 0.0741
# Epoch 117/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8797 - accuracy: 0.3108 - val_loss: 5.7675 - val_accuracy: 0.0732
# Epoch 118/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8723 - accuracy: 0.3134 - val_loss: 5.7788 - val_accuracy: 0.0738
# Epoch 119/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8669 - accuracy: 0.3116 - val_loss: 5.7893 - val_accuracy: 0.0738
# Epoch 120/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8602 - accuracy: 0.3137 - val_loss: 5.7929 - val_accuracy: 0.0744
# Epoch 121/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8540 - accuracy: 0.3156 - val_loss: 5.8041 - val_accuracy: 0.0738
# Epoch 122/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8488 - accuracy: 0.3157 - val_loss: 5.8130 - val_accuracy: 0.0735
# Epoch 123/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8402 - accuracy: 0.3175 - val_loss: 5.8241 - val_accuracy: 0.0726
# Epoch 124/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8339 - accuracy: 0.3185 - val_loss: 5.8298 - val_accuracy: 0.0735
# Epoch 125/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.8273 - accuracy: 0.3193 - val_loss: 5.8448 - val_accuracy: 0.0700
# Epoch 126/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8208 - accuracy: 0.3197 - val_loss: 5.8498 - val_accuracy: 0.0720
# Epoch 127/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8135 - accuracy: 0.3209 - val_loss: 5.8543 - val_accuracy: 0.0718
# Epoch 128/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8084 - accuracy: 0.3222 - val_loss: 5.8732 - val_accuracy: 0.0712
# Epoch 129/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.8012 - accuracy: 0.3227 - val_loss: 5.8796 - val_accuracy: 0.0712
# Epoch 130/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7947 - accuracy: 0.3244 - val_loss: 5.8836 - val_accuracy: 0.0703
# Epoch 131/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7863 - accuracy: 0.3258 - val_loss: 5.8912 - val_accuracy: 0.0694
# Epoch 132/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7813 - accuracy: 0.3262 - val_loss: 5.9023 - val_accuracy: 0.0703
# Epoch 133/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7754 - accuracy: 0.3281 - val_loss: 5.9055 - val_accuracy: 0.0712
# Epoch 134/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7698 - accuracy: 0.3275 - val_loss: 5.9110 - val_accuracy: 0.0692
# Epoch 135/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7655 - accuracy: 0.3268 - val_loss: 5.9240 - val_accuracy: 0.0712
# Epoch 136/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7595 - accuracy: 0.3297 - val_loss: 5.9262 - val_accuracy: 0.0726
# Epoch 137/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7522 - accuracy: 0.3315 - val_loss: 5.9307 - val_accuracy: 0.0735
# Epoch 138/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7455 - accuracy: 0.3310 - val_loss: 5.9413 - val_accuracy: 0.0694
# Epoch 139/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7380 - accuracy: 0.3327 - val_loss: 5.9506 - val_accuracy: 0.0715
# Epoch 140/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7327 - accuracy: 0.3338 - val_loss: 5.9532 - val_accuracy: 0.0709
# Epoch 141/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7264 - accuracy: 0.3338 - val_loss: 5.9629 - val_accuracy: 0.0715
# Epoch 142/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7197 - accuracy: 0.3351 - val_loss: 5.9638 - val_accuracy: 0.0720
# Epoch 143/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.7141 - accuracy: 0.3370 - val_loss: 5.9770 - val_accuracy: 0.0686
# Epoch 144/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7085 - accuracy: 0.3373 - val_loss: 5.9773 - val_accuracy: 0.0735
# Epoch 145/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.7031 - accuracy: 0.3367 - val_loss: 5.9897 - val_accuracy: 0.0718
# Epoch 146/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6971 - accuracy: 0.3377 - val_loss: 5.9968 - val_accuracy: 0.0692
# Epoch 147/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6923 - accuracy: 0.3409 - val_loss: 5.9982 - val_accuracy: 0.0709
# Epoch 148/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6847 - accuracy: 0.3408 - val_loss: 6.0087 - val_accuracy: 0.0715
# Epoch 149/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6787 - accuracy: 0.3419 - val_loss: 6.0132 - val_accuracy: 0.0700
# Epoch 150/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6743 - accuracy: 0.3425 - val_loss: 6.0231 - val_accuracy: 0.0692
# Epoch 151/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6675 - accuracy: 0.3441 - val_loss: 6.0373 - val_accuracy: 0.0663
# Epoch 152/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6618 - accuracy: 0.3460 - val_loss: 6.0366 - val_accuracy: 0.0697
# Epoch 153/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6568 - accuracy: 0.3468 - val_loss: 6.0450 - val_accuracy: 0.0694
# Epoch 154/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6497 - accuracy: 0.3484 - val_loss: 6.0367 - val_accuracy: 0.0692
# Epoch 155/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6449 - accuracy: 0.3484 - val_loss: 6.0624 - val_accuracy: 0.0663
# Epoch 156/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6385 - accuracy: 0.3494 - val_loss: 6.0513 - val_accuracy: 0.0700
# Epoch 157/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6328 - accuracy: 0.3505 - val_loss: 6.0675 - val_accuracy: 0.0686
# Epoch 158/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6265 - accuracy: 0.3525 - val_loss: 6.0727 - val_accuracy: 0.0692
# Epoch 159/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6214 - accuracy: 0.3537 - val_loss: 6.0775 - val_accuracy: 0.0712
# Epoch 160/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6175 - accuracy: 0.3547 - val_loss: 6.0883 - val_accuracy: 0.0663
# Epoch 161/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6120 - accuracy: 0.3540 - val_loss: 6.1001 - val_accuracy: 0.0663
# Epoch 162/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.6077 - accuracy: 0.3571 - val_loss: 6.1017 - val_accuracy: 0.0677
# Epoch 163/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.6016 - accuracy: 0.3572 - val_loss: 6.1065 - val_accuracy: 0.0680
# Epoch 164/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5958 - accuracy: 0.3582 - val_loss: 6.1166 - val_accuracy: 0.0683
# Epoch 165/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5908 - accuracy: 0.3587 - val_loss: 6.1172 - val_accuracy: 0.0683
# Epoch 166/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5878 - accuracy: 0.3593 - val_loss: 6.1385 - val_accuracy: 0.0666
# Epoch 167/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5823 - accuracy: 0.3600 - val_loss: 6.1441 - val_accuracy: 0.0648
# Epoch 168/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5772 - accuracy: 0.3615 - val_loss: 6.1408 - val_accuracy: 0.0663
# Epoch 169/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5706 - accuracy: 0.3624 - val_loss: 6.1583 - val_accuracy: 0.0648
# Epoch 170/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5669 - accuracy: 0.3627 - val_loss: 6.1579 - val_accuracy: 0.0666
# Epoch 171/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5614 - accuracy: 0.3634 - val_loss: 6.1537 - val_accuracy: 0.0666
# Epoch 172/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5572 - accuracy: 0.3654 - val_loss: 6.1762 - val_accuracy: 0.0651
# Epoch 173/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5548 - accuracy: 0.3659 - val_loss: 6.1730 - val_accuracy: 0.0663
# Epoch 174/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5497 - accuracy: 0.3660 - val_loss: 6.1922 - val_accuracy: 0.0642
# Epoch 175/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5446 - accuracy: 0.3645 - val_loss: 6.1887 - val_accuracy: 0.0660
# Epoch 176/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5400 - accuracy: 0.3689 - val_loss: 6.1866 - val_accuracy: 0.0680
# Epoch 177/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5359 - accuracy: 0.3670 - val_loss: 6.2087 - val_accuracy: 0.0634
# Epoch 178/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.5312 - accuracy: 0.3665 - val_loss: 6.1828 - val_accuracy: 0.0689
# Epoch 179/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5274 - accuracy: 0.3696 - val_loss: 6.2128 - val_accuracy: 0.0648
# Epoch 180/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5206 - accuracy: 0.3709 - val_loss: 6.2101 - val_accuracy: 0.0648
# Epoch 181/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5172 - accuracy: 0.3717 - val_loss: 6.2211 - val_accuracy: 0.0645
# Epoch 182/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5118 - accuracy: 0.3727 - val_loss: 6.2276 - val_accuracy: 0.0645
# Epoch 183/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5058 - accuracy: 0.3728 - val_loss: 6.2383 - val_accuracy: 0.0616
# Epoch 184/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5024 - accuracy: 0.3759 - val_loss: 6.2321 - val_accuracy: 0.0628
# Epoch 185/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.5000 - accuracy: 0.3732 - val_loss: 6.2578 - val_accuracy: 0.0631
# Epoch 186/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4951 - accuracy: 0.3767 - val_loss: 6.2570 - val_accuracy: 0.0622
# Epoch 187/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4907 - accuracy: 0.3780 - val_loss: 6.2699 - val_accuracy: 0.0590
# Epoch 188/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4844 - accuracy: 0.3794 - val_loss: 6.2736 - val_accuracy: 0.0619
# Epoch 189/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4815 - accuracy: 0.3791 - val_loss: 6.2808 - val_accuracy: 0.0590
# Epoch 190/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4765 - accuracy: 0.3798 - val_loss: 6.2836 - val_accuracy: 0.0584
# Epoch 191/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4714 - accuracy: 0.3801 - val_loss: 6.2954 - val_accuracy: 0.0590
# Epoch 192/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4675 - accuracy: 0.3821 - val_loss: 6.3029 - val_accuracy: 0.0587
# Epoch 193/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4643 - accuracy: 0.3815 - val_loss: 6.3062 - val_accuracy: 0.0605
# Epoch 194/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4593 - accuracy: 0.3839 - val_loss: 6.3135 - val_accuracy: 0.0590
# Epoch 195/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4525 - accuracy: 0.3842 - val_loss: 6.3228 - val_accuracy: 0.0590
# Epoch 196/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4484 - accuracy: 0.3865 - val_loss: 6.3246 - val_accuracy: 0.0590
# Epoch 197/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4446 - accuracy: 0.3873 - val_loss: 6.3359 - val_accuracy: 0.0590
# Epoch 198/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4416 - accuracy: 0.3856 - val_loss: 6.3445 - val_accuracy: 0.0596
# Epoch 199/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4365 - accuracy: 0.3883 - val_loss: 6.3498 - val_accuracy: 0.0584
# Epoch 200/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4333 - accuracy: 0.3900 - val_loss: 6.3604 - val_accuracy: 0.0561
# Epoch 201/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4297 - accuracy: 0.3898 - val_loss: 6.3627 - val_accuracy: 0.0593
# Epoch 202/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4256 - accuracy: 0.3897 - val_loss: 6.3664 - val_accuracy: 0.0596
# Epoch 203/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4202 - accuracy: 0.3925 - val_loss: 6.3833 - val_accuracy: 0.0579
# Epoch 204/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4167 - accuracy: 0.3895 - val_loss: 6.3798 - val_accuracy: 0.0582
# Epoch 205/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4119 - accuracy: 0.3936 - val_loss: 6.3963 - val_accuracy: 0.0564
# Epoch 206/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.4071 - accuracy: 0.3920 - val_loss: 6.3997 - val_accuracy: 0.0582
# Epoch 207/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.4030 - accuracy: 0.3933 - val_loss: 6.4034 - val_accuracy: 0.0576
# Epoch 208/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3993 - accuracy: 0.3955 - val_loss: 6.4085 - val_accuracy: 0.0584
# Epoch 209/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3950 - accuracy: 0.3955 - val_loss: 6.4155 - val_accuracy: 0.0579
# Epoch 210/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3921 - accuracy: 0.3979 - val_loss: 6.4231 - val_accuracy: 0.0570
# Epoch 211/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3902 - accuracy: 0.3970 - val_loss: 6.4326 - val_accuracy: 0.0576
# Epoch 212/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3873 - accuracy: 0.3953 - val_loss: 6.4299 - val_accuracy: 0.0564
# Epoch 213/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3846 - accuracy: 0.3966 - val_loss: 6.4399 - val_accuracy: 0.0567
# Epoch 214/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3812 - accuracy: 0.3964 - val_loss: 6.4444 - val_accuracy: 0.0558
# Epoch 215/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3760 - accuracy: 0.3982 - val_loss: 6.4514 - val_accuracy: 0.0567
# Epoch 216/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3742 - accuracy: 0.3995 - val_loss: 6.4558 - val_accuracy: 0.0590
# Epoch 217/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3688 - accuracy: 0.4006 - val_loss: 6.4591 - val_accuracy: 0.0573
# Epoch 218/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3666 - accuracy: 0.4004 - val_loss: 6.4738 - val_accuracy: 0.0576
# Epoch 219/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3631 - accuracy: 0.3998 - val_loss: 6.4752 - val_accuracy: 0.0576
# Epoch 220/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3592 - accuracy: 0.4015 - val_loss: 6.4728 - val_accuracy: 0.0573
# Epoch 221/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3539 - accuracy: 0.4037 - val_loss: 6.4795 - val_accuracy: 0.0561
# Epoch 222/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3536 - accuracy: 0.4020 - val_loss: 6.4908 - val_accuracy: 0.0564
# Epoch 223/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3497 - accuracy: 0.4035 - val_loss: 6.4878 - val_accuracy: 0.0584
# Epoch 224/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3463 - accuracy: 0.4044 - val_loss: 6.4960 - val_accuracy: 0.0567
# Epoch 225/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3426 - accuracy: 0.4051 - val_loss: 6.4943 - val_accuracy: 0.0558
# Epoch 226/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3394 - accuracy: 0.4072 - val_loss: 6.5061 - val_accuracy: 0.0567
# Epoch 227/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3359 - accuracy: 0.4065 - val_loss: 6.5018 - val_accuracy: 0.0576
# Epoch 228/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3317 - accuracy: 0.4090 - val_loss: 6.5294 - val_accuracy: 0.0579
# Epoch 229/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3303 - accuracy: 0.4069 - val_loss: 6.5288 - val_accuracy: 0.0573
# Epoch 230/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3290 - accuracy: 0.4072 - val_loss: 6.5188 - val_accuracy: 0.0579
# Epoch 231/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3249 - accuracy: 0.4089 - val_loss: 6.5330 - val_accuracy: 0.0570
# Epoch 232/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3199 - accuracy: 0.4114 - val_loss: 6.5393 - val_accuracy: 0.0561
# Epoch 233/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3168 - accuracy: 0.4114 - val_loss: 6.5542 - val_accuracy: 0.0567
# Epoch 234/2000
# 9/9 [==============================] - 1s 72ms/step - loss: 1.3140 - accuracy: 0.4111 - val_loss: 6.5452 - val_accuracy: 0.0561
# Epoch 235/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3111 - accuracy: 0.4111 - val_loss: 6.5696 - val_accuracy: 0.0567
# Epoch 236/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.3082 - accuracy: 0.4113 - val_loss: 6.5677 - val_accuracy: 0.0573
# Epoch 237/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.3041 - accuracy: 0.4143 - val_loss: 6.5780 - val_accuracy: 0.0547
# Epoch 238/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2988 - accuracy: 0.4146 - val_loss: 6.5803 - val_accuracy: 0.0553
# Epoch 239/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2962 - accuracy: 0.4151 - val_loss: 6.5908 - val_accuracy: 0.0558
# Epoch 240/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2945 - accuracy: 0.4152 - val_loss: 6.5901 - val_accuracy: 0.0558
# Epoch 241/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2900 - accuracy: 0.4167 - val_loss: 6.5975 - val_accuracy: 0.0561
# Epoch 242/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2890 - accuracy: 0.4166 - val_loss: 6.6114 - val_accuracy: 0.0556
# Epoch 243/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2855 - accuracy: 0.4190 - val_loss: 6.6066 - val_accuracy: 0.0567
# Epoch 244/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2849 - accuracy: 0.4186 - val_loss: 6.6169 - val_accuracy: 0.0556
# Epoch 245/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2783 - accuracy: 0.4196 - val_loss: 6.6242 - val_accuracy: 0.0538
# Epoch 246/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2747 - accuracy: 0.4205 - val_loss: 6.6232 - val_accuracy: 0.0564
# Epoch 247/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2706 - accuracy: 0.4214 - val_loss: 6.6278 - val_accuracy: 0.0541
# Epoch 248/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2661 - accuracy: 0.4231 - val_loss: 6.6398 - val_accuracy: 0.0544
# Epoch 249/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2636 - accuracy: 0.4246 - val_loss: 6.6359 - val_accuracy: 0.0556
# Epoch 250/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2620 - accuracy: 0.4233 - val_loss: 6.6414 - val_accuracy: 0.0550
# Epoch 251/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2601 - accuracy: 0.4248 - val_loss: 6.6453 - val_accuracy: 0.0544
# Epoch 252/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2567 - accuracy: 0.4265 - val_loss: 6.6599 - val_accuracy: 0.0553
# Epoch 253/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2533 - accuracy: 0.4259 - val_loss: 6.6597 - val_accuracy: 0.0556
# Epoch 254/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2492 - accuracy: 0.4258 - val_loss: 6.6710 - val_accuracy: 0.0550
# Epoch 255/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2465 - accuracy: 0.4289 - val_loss: 6.6730 - val_accuracy: 0.0547
# Epoch 256/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2440 - accuracy: 0.4295 - val_loss: 6.6812 - val_accuracy: 0.0544
# Epoch 257/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2421 - accuracy: 0.4300 - val_loss: 6.6806 - val_accuracy: 0.0544
# Epoch 258/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2394 - accuracy: 0.4291 - val_loss: 6.6870 - val_accuracy: 0.0553
# Epoch 259/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2361 - accuracy: 0.4297 - val_loss: 6.6965 - val_accuracy: 0.0547
# Epoch 260/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2357 - accuracy: 0.4293 - val_loss: 6.6973 - val_accuracy: 0.0547
# Epoch 261/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2353 - accuracy: 0.4311 - val_loss: 6.7033 - val_accuracy: 0.0553
# Epoch 262/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2322 - accuracy: 0.4323 - val_loss: 6.7015 - val_accuracy: 0.0541
# Epoch 263/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2301 - accuracy: 0.4315 - val_loss: 6.7134 - val_accuracy: 0.0550
# Epoch 264/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2282 - accuracy: 0.4304 - val_loss: 6.7155 - val_accuracy: 0.0553
# Epoch 265/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2274 - accuracy: 0.4332 - val_loss: 6.7348 - val_accuracy: 0.0541
# Epoch 266/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2257 - accuracy: 0.4317 - val_loss: 6.7332 - val_accuracy: 0.0561
# Epoch 267/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2215 - accuracy: 0.4325 - val_loss: 6.7310 - val_accuracy: 0.0570
# Epoch 268/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2177 - accuracy: 0.4337 - val_loss: 6.7313 - val_accuracy: 0.0564
# Epoch 269/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2167 - accuracy: 0.4335 - val_loss: 6.7373 - val_accuracy: 0.0561
# Epoch 270/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2142 - accuracy: 0.4342 - val_loss: 6.7453 - val_accuracy: 0.0547
# Epoch 271/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2107 - accuracy: 0.4366 - val_loss: 6.7435 - val_accuracy: 0.0564
# Epoch 272/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2062 - accuracy: 0.4368 - val_loss: 6.7534 - val_accuracy: 0.0564
# Epoch 273/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2049 - accuracy: 0.4384 - val_loss: 6.7581 - val_accuracy: 0.0553
# Epoch 274/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.2038 - accuracy: 0.4405 - val_loss: 6.7651 - val_accuracy: 0.0550
# Epoch 275/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.2009 - accuracy: 0.4396 - val_loss: 6.7690 - val_accuracy: 0.0538
# Epoch 276/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1983 - accuracy: 0.4398 - val_loss: 6.7716 - val_accuracy: 0.0553
# Epoch 277/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1977 - accuracy: 0.4397 - val_loss: 6.7857 - val_accuracy: 0.0547
# Epoch 278/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1951 - accuracy: 0.4404 - val_loss: 6.7929 - val_accuracy: 0.0558
# Epoch 279/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1906 - accuracy: 0.4409 - val_loss: 6.7898 - val_accuracy: 0.0550
# Epoch 280/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1891 - accuracy: 0.4402 - val_loss: 6.8025 - val_accuracy: 0.0547
# Epoch 281/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1866 - accuracy: 0.4422 - val_loss: 6.8164 - val_accuracy: 0.0553
# Epoch 282/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1858 - accuracy: 0.4425 - val_loss: 6.8036 - val_accuracy: 0.0550
# Epoch 283/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1843 - accuracy: 0.4421 - val_loss: 6.8203 - val_accuracy: 0.0550
# Epoch 284/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1817 - accuracy: 0.4429 - val_loss: 6.8239 - val_accuracy: 0.0530
# Epoch 285/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1778 - accuracy: 0.4440 - val_loss: 6.8295 - val_accuracy: 0.0532
# Epoch 286/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1758 - accuracy: 0.4436 - val_loss: 6.8299 - val_accuracy: 0.0538
# Epoch 287/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1710 - accuracy: 0.4449 - val_loss: 6.8270 - val_accuracy: 0.0535
# Epoch 288/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1694 - accuracy: 0.4451 - val_loss: 6.8304 - val_accuracy: 0.0521
# Epoch 289/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1658 - accuracy: 0.4458 - val_loss: 6.8424 - val_accuracy: 0.0541
# Epoch 290/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1650 - accuracy: 0.4472 - val_loss: 6.8359 - val_accuracy: 0.0535
# Epoch 291/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1625 - accuracy: 0.4480 - val_loss: 6.8383 - val_accuracy: 0.0527
# Epoch 292/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1598 - accuracy: 0.4488 - val_loss: 6.8569 - val_accuracy: 0.0518
# Epoch 293/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1556 - accuracy: 0.4490 - val_loss: 6.8565 - val_accuracy: 0.0530
# Epoch 294/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1528 - accuracy: 0.4497 - val_loss: 6.8576 - val_accuracy: 0.0518
# Epoch 295/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1497 - accuracy: 0.4518 - val_loss: 6.8599 - val_accuracy: 0.0532
# Epoch 296/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1495 - accuracy: 0.4504 - val_loss: 6.8700 - val_accuracy: 0.0544
# Epoch 297/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1477 - accuracy: 0.4517 - val_loss: 6.8809 - val_accuracy: 0.0524
# Epoch 298/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1484 - accuracy: 0.4507 - val_loss: 6.8792 - val_accuracy: 0.0512
# Epoch 299/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1479 - accuracy: 0.4509 - val_loss: 6.8748 - val_accuracy: 0.0538
# Epoch 300/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1471 - accuracy: 0.4519 - val_loss: 6.8784 - val_accuracy: 0.0530
# Epoch 301/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1433 - accuracy: 0.4522 - val_loss: 6.8876 - val_accuracy: 0.0521
# Epoch 302/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1407 - accuracy: 0.4548 - val_loss: 6.8986 - val_accuracy: 0.0524
# Epoch 303/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1380 - accuracy: 0.4523 - val_loss: 6.8875 - val_accuracy: 0.0547
# Epoch 304/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1377 - accuracy: 0.4524 - val_loss: 6.8957 - val_accuracy: 0.0550
# Epoch 305/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1350 - accuracy: 0.4534 - val_loss: 6.9117 - val_accuracy: 0.0518
# Epoch 306/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1315 - accuracy: 0.4551 - val_loss: 6.8994 - val_accuracy: 0.0538
# Epoch 307/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1264 - accuracy: 0.4551 - val_loss: 6.9098 - val_accuracy: 0.0524
# Epoch 308/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1262 - accuracy: 0.4560 - val_loss: 6.9083 - val_accuracy: 0.0541
# Epoch 309/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1249 - accuracy: 0.4543 - val_loss: 6.9157 - val_accuracy: 0.0544
# Epoch 310/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1223 - accuracy: 0.4575 - val_loss: 6.9243 - val_accuracy: 0.0527
# Epoch 311/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1230 - accuracy: 0.4564 - val_loss: 6.9291 - val_accuracy: 0.0541
# Epoch 312/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1175 - accuracy: 0.4568 - val_loss: 6.9368 - val_accuracy: 0.0538
# Epoch 313/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1146 - accuracy: 0.4594 - val_loss: 6.9474 - val_accuracy: 0.0530
# Epoch 314/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1139 - accuracy: 0.4588 - val_loss: 6.9497 - val_accuracy: 0.0541
# Epoch 315/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1115 - accuracy: 0.4590 - val_loss: 6.9574 - val_accuracy: 0.0538
# Epoch 316/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1097 - accuracy: 0.4598 - val_loss: 6.9506 - val_accuracy: 0.0532
# Epoch 317/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1093 - accuracy: 0.4575 - val_loss: 6.9556 - val_accuracy: 0.0532
# Epoch 318/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1072 - accuracy: 0.4606 - val_loss: 6.9588 - val_accuracy: 0.0544
# Epoch 319/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1031 - accuracy: 0.4602 - val_loss: 6.9673 - val_accuracy: 0.0541
# Epoch 320/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1025 - accuracy: 0.4607 - val_loss: 6.9740 - val_accuracy: 0.0535
# Epoch 321/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.1022 - accuracy: 0.4612 - val_loss: 6.9720 - val_accuracy: 0.0538
# Epoch 322/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.1003 - accuracy: 0.4596 - val_loss: 6.9798 - val_accuracy: 0.0538
# Epoch 323/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0953 - accuracy: 0.4623 - val_loss: 6.9913 - val_accuracy: 0.0518
# Epoch 324/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0926 - accuracy: 0.4655 - val_loss: 6.9862 - val_accuracy: 0.0553
# Epoch 325/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.0927 - accuracy: 0.4652 - val_loss: 6.9951 - val_accuracy: 0.0544
# Epoch 326/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0917 - accuracy: 0.4637 - val_loss: 6.9917 - val_accuracy: 0.0538
# Epoch 327/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.0900 - accuracy: 0.4639 - val_loss: 7.0105 - val_accuracy: 0.0558
# Epoch 328/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0902 - accuracy: 0.4646 - val_loss: 7.0130 - val_accuracy: 0.0527
# Epoch 329/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0877 - accuracy: 0.4639 - val_loss: 7.0075 - val_accuracy: 0.0538
# Epoch 330/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0856 - accuracy: 0.4652 - val_loss: 7.0114 - val_accuracy: 0.0541
# Epoch 331/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0842 - accuracy: 0.4636 - val_loss: 7.0143 - val_accuracy: 0.0544
# Epoch 332/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0820 - accuracy: 0.4655 - val_loss: 7.0227 - val_accuracy: 0.0530
# Epoch 333/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.0804 - accuracy: 0.4676 - val_loss: 7.0200 - val_accuracy: 0.0527
# Epoch 334/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0760 - accuracy: 0.4677 - val_loss: 7.0317 - val_accuracy: 0.0547
# Epoch 335/2000
# 9/9 [==============================] - 1s 73ms/step - loss: 1.0721 - accuracy: 0.4685 - val_loss: 7.0228 - val_accuracy: 0.0544
# Epoch 336/2000
# 9/9 [==============================] - 1s 74ms/step - loss: 1.0711 - accuracy: 0.4679 - val_loss: 7.0480 - val_accuracy: 0.0535
# Epoch 337/2000
# ...
# Epoch 1891/2000
# 9/9 [==============================] - 1s 134ms/step - loss: 0.6578 - accuracy: 0.5531 - val_loss: 8.7602 - val_accuracy: 0.0466
# Epoch 1892/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.6570 - accuracy: 0.5520 - val_loss: 8.7558 - val_accuracy: 0.0460
# Epoch 1893/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.6588 - accuracy: 0.5530 - val_loss: 8.7497 - val_accuracy: 0.0472
# Epoch 1894/2000
# 9/9 [==============================] - 1s 138ms/step - loss: 0.6587 - accuracy: 0.5532 - val_loss: 8.7636 - val_accuracy: 0.0448
# Epoch 1895/2000
# 9/9 [==============================] - 1s 150ms/step - loss: 0.6552 - accuracy: 0.5525 - val_loss: 8.7190 - val_accuracy: 0.0492
# Epoch 1896/2000
# 9/9 [==============================] - 1s 149ms/step - loss: 0.6604 - accuracy: 0.5517 - val_loss: 8.7653 - val_accuracy: 0.0431
# Epoch 1897/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6627 - accuracy: 0.5512 - val_loss: 8.7335 - val_accuracy: 0.0463
# Epoch 1898/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6594 - accuracy: 0.5519 - val_loss: 8.7470 - val_accuracy: 0.0463
# Epoch 1899/2000
# 9/9 [==============================] - 1s 148ms/step - loss: 0.6672 - accuracy: 0.5517 - val_loss: 8.7294 - val_accuracy: 0.0489
# Epoch 1900/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6744 - accuracy: 0.5493 - val_loss: 8.7654 - val_accuracy: 0.0489
# Epoch 1901/2000
# 9/9 [==============================] - 1s 155ms/step - loss: 0.6892 - accuracy: 0.5454 - val_loss: 8.7545 - val_accuracy: 0.0506
# Epoch 1902/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6964 - accuracy: 0.5412 - val_loss: 8.7497 - val_accuracy: 0.0483
# Epoch 1903/2000
# 9/9 [==============================] - 1s 150ms/step - loss: 0.6901 - accuracy: 0.5434 - val_loss: 8.7621 - val_accuracy: 0.0498
# Epoch 1904/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6974 - accuracy: 0.5417 - val_loss: 8.7158 - val_accuracy: 0.0515
# Epoch 1905/2000
# 9/9 [==============================] - 1s 155ms/step - loss: 0.6917 - accuracy: 0.5431 - val_loss: 8.7660 - val_accuracy: 0.0501
# Epoch 1906/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6912 - accuracy: 0.5446 - val_loss: 8.7622 - val_accuracy: 0.0506
# Epoch 1907/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6827 - accuracy: 0.5457 - val_loss: 8.7429 - val_accuracy: 0.0518
# Epoch 1908/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6765 - accuracy: 0.5486 - val_loss: 8.7720 - val_accuracy: 0.0466
# Epoch 1909/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6745 - accuracy: 0.5470 - val_loss: 8.7201 - val_accuracy: 0.0498
# Epoch 1910/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6716 - accuracy: 0.5502 - val_loss: 8.7416 - val_accuracy: 0.0483
# Epoch 1911/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6678 - accuracy: 0.5497 - val_loss: 8.7539 - val_accuracy: 0.0489
# Epoch 1912/2000
# 9/9 [==============================] - 1s 148ms/step - loss: 0.6694 - accuracy: 0.5507 - val_loss: 8.7499 - val_accuracy: 0.0489
# Epoch 1913/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6663 - accuracy: 0.5504 - val_loss: 8.7548 - val_accuracy: 0.0472
# Epoch 1914/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6619 - accuracy: 0.5520 - val_loss: 8.7697 - val_accuracy: 0.0472
# Epoch 1915/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6570 - accuracy: 0.5531 - val_loss: 8.7630 - val_accuracy: 0.0498
# Epoch 1916/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6553 - accuracy: 0.5515 - val_loss: 8.7618 - val_accuracy: 0.0486
# Epoch 1917/2000
# 9/9 [==============================] - 1s 164ms/step - loss: 0.6545 - accuracy: 0.5531 - val_loss: 8.7640 - val_accuracy: 0.0480
# Epoch 1918/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6521 - accuracy: 0.5538 - val_loss: 8.7495 - val_accuracy: 0.0512
# Epoch 1919/2000
# 9/9 [==============================] - 1s 153ms/step - loss: 0.6507 - accuracy: 0.5536 - val_loss: 8.7516 - val_accuracy: 0.0503
# Epoch 1920/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6494 - accuracy: 0.5547 - val_loss: 8.7476 - val_accuracy: 0.0498
# Epoch 1921/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6481 - accuracy: 0.5536 - val_loss: 8.7476 - val_accuracy: 0.0486
# Epoch 1922/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6471 - accuracy: 0.5544 - val_loss: 8.7538 - val_accuracy: 0.0509
# Epoch 1923/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6464 - accuracy: 0.5557 - val_loss: 8.7499 - val_accuracy: 0.0498
# Epoch 1924/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6459 - accuracy: 0.5555 - val_loss: 8.7564 - val_accuracy: 0.0489
# Epoch 1925/2000
# 9/9 [==============================] - 1s 162ms/step - loss: 0.6439 - accuracy: 0.5556 - val_loss: 8.7441 - val_accuracy: 0.0495
# Epoch 1926/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6429 - accuracy: 0.5549 - val_loss: 8.7505 - val_accuracy: 0.0503
# Epoch 1927/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6421 - accuracy: 0.5553 - val_loss: 8.7575 - val_accuracy: 0.0503
# Epoch 1928/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6451 - accuracy: 0.5553 - val_loss: 8.7389 - val_accuracy: 0.0498
# Epoch 1929/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6431 - accuracy: 0.5547 - val_loss: 8.7406 - val_accuracy: 0.0503
# Epoch 1930/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6443 - accuracy: 0.5536 - val_loss: 8.7460 - val_accuracy: 0.0512
# Epoch 1931/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6441 - accuracy: 0.5550 - val_loss: 8.7534 - val_accuracy: 0.0509
# Epoch 1932/2000
# 9/9 [==============================] - 1s 155ms/step - loss: 0.6450 - accuracy: 0.5557 - val_loss: 8.7441 - val_accuracy: 0.0509
# Epoch 1933/2000
# 9/9 [==============================] - 1s 159ms/step - loss: 0.6419 - accuracy: 0.5564 - val_loss: 8.7459 - val_accuracy: 0.0509
# Epoch 1934/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6419 - accuracy: 0.5557 - val_loss: 8.7497 - val_accuracy: 0.0515
# Epoch 1935/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6415 - accuracy: 0.5550 - val_loss: 8.7587 - val_accuracy: 0.0512
# Epoch 1936/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6401 - accuracy: 0.5561 - val_loss: 8.7454 - val_accuracy: 0.0509
# Epoch 1937/2000
# 9/9 [==============================] - 1s 153ms/step - loss: 0.6400 - accuracy: 0.5557 - val_loss: 8.7284 - val_accuracy: 0.0515
# Epoch 1938/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6389 - accuracy: 0.5555 - val_loss: 8.7432 - val_accuracy: 0.0518
# Epoch 1939/2000
# 9/9 [==============================] - 1s 164ms/step - loss: 0.6383 - accuracy: 0.5565 - val_loss: 8.7462 - val_accuracy: 0.0509
# Epoch 1940/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6384 - accuracy: 0.5552 - val_loss: 8.7376 - val_accuracy: 0.0501
# Epoch 1941/2000
# 9/9 [==============================] - 1s 163ms/step - loss: 0.6381 - accuracy: 0.5548 - val_loss: 8.7368 - val_accuracy: 0.0501
# Epoch 1942/2000
# 9/9 [==============================] - 1s 152ms/step - loss: 0.6368 - accuracy: 0.5557 - val_loss: 8.7391 - val_accuracy: 0.0498
# Epoch 1943/2000
# 9/9 [==============================] - 1s 147ms/step - loss: 0.6379 - accuracy: 0.5546 - val_loss: 8.7322 - val_accuracy: 0.0509
# Epoch 1944/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6384 - accuracy: 0.5555 - val_loss: 8.7356 - val_accuracy: 0.0503
# Epoch 1945/2000
# 9/9 [==============================] - 1s 159ms/step - loss: 0.6375 - accuracy: 0.5560 - val_loss: 8.7380 - val_accuracy: 0.0495
# Epoch 1946/2000
# 9/9 [==============================] - 1s 139ms/step - loss: 0.6363 - accuracy: 0.5562 - val_loss: 8.7366 - val_accuracy: 0.0501
# Epoch 1947/2000
# 9/9 [==============================] - 1s 159ms/step - loss: 0.6364 - accuracy: 0.5560 - val_loss: 8.7403 - val_accuracy: 0.0506
# Epoch 1948/2000
# 9/9 [==============================] - 1s 151ms/step - loss: 0.6377 - accuracy: 0.5565 - val_loss: 8.7422 - val_accuracy: 0.0498
# Epoch 1949/2000
# 9/9 [==============================] - 1s 147ms/step - loss: 0.6377 - accuracy: 0.5560 - val_loss: 8.7324 - val_accuracy: 0.0509
# Epoch 1950/2000
# 9/9 [==============================] - 1s 151ms/step - loss: 0.6369 - accuracy: 0.5552 - val_loss: 8.7343 - val_accuracy: 0.0509
# Epoch 1951/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6355 - accuracy: 0.5566 - val_loss: 8.7412 - val_accuracy: 0.0495
# Epoch 1952/2000
# 9/9 [==============================] - 1s 147ms/step - loss: 0.6356 - accuracy: 0.5563 - val_loss: 8.7414 - val_accuracy: 0.0483
# Epoch 1953/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6353 - accuracy: 0.5557 - val_loss: 8.7462 - val_accuracy: 0.0495
# Epoch 1954/2000
# 9/9 [==============================] - 1s 145ms/step - loss: 0.6353 - accuracy: 0.5552 - val_loss: 8.7389 - val_accuracy: 0.0509
# Epoch 1955/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6347 - accuracy: 0.5567 - val_loss: 8.7394 - val_accuracy: 0.0501
# Epoch 1956/2000
# 9/9 [==============================] - 1s 150ms/step - loss: 0.6349 - accuracy: 0.5562 - val_loss: 8.7479 - val_accuracy: 0.0495
# Epoch 1957/2000
# 9/9 [==============================] - 1s 153ms/step - loss: 0.6356 - accuracy: 0.5559 - val_loss: 8.7501 - val_accuracy: 0.0498
# Epoch 1958/2000
# 9/9 [==============================] - 1s 164ms/step - loss: 0.6355 - accuracy: 0.5562 - val_loss: 8.7434 - val_accuracy: 0.0503
# Epoch 1959/2000
# 9/9 [==============================] - 1s 161ms/step - loss: 0.6342 - accuracy: 0.5565 - val_loss: 8.7467 - val_accuracy: 0.0498
# Epoch 1960/2000
# 9/9 [==============================] - 1s 145ms/step - loss: 0.6358 - accuracy: 0.5568 - val_loss: 8.7379 - val_accuracy: 0.0492
# Epoch 1961/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6355 - accuracy: 0.5559 - val_loss: 8.7435 - val_accuracy: 0.0506
# Epoch 1962/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6356 - accuracy: 0.5571 - val_loss: 8.7503 - val_accuracy: 0.0495
# Epoch 1963/2000
# 9/9 [==============================] - 1s 143ms/step - loss: 0.6347 - accuracy: 0.5563 - val_loss: 8.7519 - val_accuracy: 0.0509
# Epoch 1964/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.6366 - accuracy: 0.5565 - val_loss: 8.7425 - val_accuracy: 0.0495
# Epoch 1965/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6378 - accuracy: 0.5553 - val_loss: 8.7363 - val_accuracy: 0.0503
# Epoch 1966/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6381 - accuracy: 0.5557 - val_loss: 8.7433 - val_accuracy: 0.0512
# Epoch 1967/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6434 - accuracy: 0.5556 - val_loss: 8.7467 - val_accuracy: 0.0509
# Epoch 1968/2000
# 9/9 [==============================] - 1s 146ms/step - loss: 0.6548 - accuracy: 0.5521 - val_loss: 8.7314 - val_accuracy: 0.0492
# Epoch 1969/2000
# 9/9 [==============================] - 1s 138ms/step - loss: 0.6595 - accuracy: 0.5499 - val_loss: 8.7363 - val_accuracy: 0.0518
# Epoch 1970/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.6779 - accuracy: 0.5461 - val_loss: 8.7434 - val_accuracy: 0.0495
# Epoch 1971/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.6726 - accuracy: 0.5483 - val_loss: 8.7178 - val_accuracy: 0.0498
# Epoch 1972/2000
# 9/9 [==============================] - 1s 133ms/step - loss: 0.6841 - accuracy: 0.5436 - val_loss: 8.7418 - val_accuracy: 0.0538
# Epoch 1973/2000
# 9/9 [==============================] - 1s 125ms/step - loss: 0.6976 - accuracy: 0.5426 - val_loss: 8.7317 - val_accuracy: 0.0532
# Epoch 1974/2000
# 9/9 [==============================] - 1s 127ms/step - loss: 0.7085 - accuracy: 0.5385 - val_loss: 8.7164 - val_accuracy: 0.0501
# Epoch 1975/2000
# 9/9 [==============================] - 1s 137ms/step - loss: 0.7084 - accuracy: 0.5369 - val_loss: 8.7420 - val_accuracy: 0.0512
# Epoch 1976/2000
# 9/9 [==============================] - 1s 129ms/step - loss: 0.7138 - accuracy: 0.5382 - val_loss: 8.7957 - val_accuracy: 0.0489
# Epoch 1977/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.7122 - accuracy: 0.5374 - val_loss: 8.7485 - val_accuracy: 0.0506
# Epoch 1978/2000
# 9/9 [==============================] - 1s 152ms/step - loss: 0.7237 - accuracy: 0.5344 - val_loss: 8.7369 - val_accuracy: 0.0477
# Epoch 1979/2000
# 9/9 [==============================] - 1s 148ms/step - loss: 0.7140 - accuracy: 0.5385 - val_loss: 8.7806 - val_accuracy: 0.0477
# Epoch 1980/2000
# 9/9 [==============================] - 1s 155ms/step - loss: 0.7116 - accuracy: 0.5363 - val_loss: 8.7426 - val_accuracy: 0.0521
# Epoch 1981/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.7004 - accuracy: 0.5391 - val_loss: 8.7535 - val_accuracy: 0.0501
# Epoch 1982/2000
# 9/9 [==============================] - 1s 153ms/step - loss: 0.6978 - accuracy: 0.5412 - val_loss: 8.7610 - val_accuracy: 0.0469
# Epoch 1983/2000
# 9/9 [==============================] - 1s 154ms/step - loss: 0.7003 - accuracy: 0.5422 - val_loss: 8.7299 - val_accuracy: 0.0506
# Epoch 1984/2000
# 9/9 [==============================] - 1s 159ms/step - loss: 0.7002 - accuracy: 0.5393 - val_loss: 8.7656 - val_accuracy: 0.0503
# Epoch 1985/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.7074 - accuracy: 0.5381 - val_loss: 8.7573 - val_accuracy: 0.0506
# Epoch 1986/2000
# 9/9 [==============================] - 1s 155ms/step - loss: 0.6901 - accuracy: 0.5445 - val_loss: 8.7479 - val_accuracy: 0.0489
# Epoch 1987/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6819 - accuracy: 0.5455 - val_loss: 8.7484 - val_accuracy: 0.0498
# Epoch 1988/2000
# 9/9 [==============================] - 1s 153ms/step - loss: 0.6750 - accuracy: 0.5492 - val_loss: 8.7232 - val_accuracy: 0.0492
# Epoch 1989/2000
# 9/9 [==============================] - 1s 159ms/step - loss: 0.6748 - accuracy: 0.5495 - val_loss: 8.7539 - val_accuracy: 0.0492
# Epoch 1990/2000
# 9/9 [==============================] - 2s 167ms/step - loss: 0.6693 - accuracy: 0.5510 - val_loss: 8.7431 - val_accuracy: 0.0524
# Epoch 1991/2000
# 9/9 [==============================] - 1s 162ms/step - loss: 0.6658 - accuracy: 0.5518 - val_loss: 8.7470 - val_accuracy: 0.0506
# Epoch 1992/2000
# 9/9 [==============================] - 1s 160ms/step - loss: 0.6636 - accuracy: 0.5515 - val_loss: 8.7391 - val_accuracy: 0.0489
# Epoch 1993/2000
# 9/9 [==============================] - 1s 158ms/step - loss: 0.6626 - accuracy: 0.5518 - val_loss: 8.7289 - val_accuracy: 0.0521
# Epoch 1994/2000
# 9/9 [==============================] - 1s 164ms/step - loss: 0.6583 - accuracy: 0.5537 - val_loss: 8.7268 - val_accuracy: 0.0527
# Epoch 1995/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6568 - accuracy: 0.5535 - val_loss: 8.7422 - val_accuracy: 0.0503
# Epoch 1996/2000
# 9/9 [==============================] - 1s 157ms/step - loss: 0.6525 - accuracy: 0.5546 - val_loss: 8.7248 - val_accuracy: 0.0503
# Epoch 1997/2000
# 9/9 [==============================] - 1s 156ms/step - loss: 0.6505 - accuracy: 0.5550 - val_loss: 8.7381 - val_accuracy: 0.0492
# Epoch 1998/2000
# 9/9 [==============================] - 1s 166ms/step - loss: 0.6490 - accuracy: 0.5550 - val_loss: 8.7316 - val_accuracy: 0.0503
# Epoch 1999/2000
# 9/9 [==============================] - 1s 152ms/step - loss: 0.6477 - accuracy: 0.5558 - val_loss: 8.7364 - val_accuracy: 0.0492
# Epoch 2000/2000
# 9/9 [==============================] - 1s 152ms/step - loss: 0.6462 - accuracy: 0.5555 - val_loss: 8.7425 - val_accuracy: 0.0495

# %%
model.save('./model/poetry')
# Out:
# WARNING:tensorflow:From /home/nancy/.local/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /home/nancy/.local/lib/python3.6/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ./model/poetry/assets

# %%
# plot some data
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# accuracies
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# ## Make a sampling model to predict

# %%
# For prediction the input size is different. We can only pass in one word at a time because we then have to use the 
# prediction as the next input.
input2=Input(shape=(1,))

# Importantly here's making use of the same layers defined earlier with the trained weights..
x = embedding_layer(input2)
# Remember that each step of the LSTM, calculation requires three inputs: The current word vector,
# the previous hidden state, and the previous cell state.
x,h,c = lstm(x,initial_state=[intial_h,intial_c])
output2=dense(x)

# sampling model will take in a single word index, a hidden state, and a cell state.
# It will output the next word probabilities, the next hidden state, and the next cell state.
sampling_model = Model([input2,intial_h,intial_c],[output2,h,c])

# %%
idx2word = {v:k for k,v in word2idx.items()}

# %%
def sample_line():
    # initial inputs
    np_input = np.array([[word2idx['<sos>']]])
    h=np.zeros((1,LATENT_DIM))
    c=np.zeros((1,LATENT_DIM))

    # so we know when to quit
    eos=word2idx['<eos>']

    # store the output here
    output_sentence=[]


    for _ in range(max_sequence_length):
        # O is a list of word probabilities for the next word. this is what we're going to take a sample from
        # H and C are the next hidden states and cell States.
        o,h,c = sampling_model.predict([np_input,h,c])
        probs = o[0,0]
        if np.argmax(probs)==0:
            print('warning')
        probs[0] = 0
        probs /= probs.sum()
        idx=np.random.choice(len(probs),p=probs)
        if idx ==eos:
            break
        output_sentence.append(idx2word.get(idx,'<WTF %s>' % idx))

        # make the next input into model
        np_input[0,0]=idx
    return ' '.join(output_sentence)

# %%
# generate a 4 line poem
for _ in range(4):
    print(sample_line())
# Out:
# a brook that was was plagued so an old cedar and show
# weep for what little things could make them glad.
# that cased the world, and he was gone!
# you can see what a lie

# %% [markdown]
# # Machine Translation with Seq2Seq
#
# We have 1 regular LSTM for the **encoder** which takes in an input sentence and then our **decoder**
# produce the translation based on what the encoder gives us.
#
# Training the **decoder** is going to be exactly like training  poetry generation model.

# %%
import os, sys
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, GRU, Dense, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# some config
BATCH_SIZE = 64  # Batch size for training.
EPOCHS = 100  # Number of epochs to train for.
LATENT_DIM = 256  # Latent dimensionality of the encoding space.
NUM_SAMPLES = 10000  # Number of samples to train on.
MAX_NUM_WORDS = 20000
EMBEDDING_DIM = 100

# %%
input_texts = [] # sentence in original language
target_texts = [] # sentence in target language
target_texts_inputs = [] # sentence in target language offset by 1

# load in the data
t=0
for line in open("./large_files/spa.txt"):
    t+=1
    if t>NUM_SAMPLES:
        break
    if '\t' not in line:
        continue
    input_text,translation,*rest = line.rstrip().split('\t')
    target_text = translation+' <eos>'
    target_text_input = '<sos> '+translation
    input_texts.append(input_text)
    target_texts.append(target_text)
    target_texts_inputs.append(target_text_input)
print("num samples:", len(input_texts))
# Out:
# num samples: 10000

# %% [markdown]
# ## Tokenization

# %% [markdown]
# ### Tokenize the inputs

# %%
## tokenize the inputs
tokenizer_input = Tokenizer(num_words=MAX_NUM_WORDS)
tokenizer_input.fit_on_texts(input_texts)
input_sequences = tokenizer_input.texts_to_sequences(input_texts)

# explanation: 
# input_texts - english sentences
# input_sequences - vectors of integers
len(input_sequences),len(input_texts)
# Out:
# (10000, 10000)

# %%
# get the word to index mapping for input language
word2idx_input = tokenizer_input.word_index
print('Found %s unique input tokens.' % len(word2idx_input))
# Out:
# Found 2355 unique input tokens.

# %%
# determine maximum length input sequence
max_input_length=max(len(s) for s in input_sequences)
max_input_length
# Out:
# 5

# %% [markdown]
# ### Tokenize the outputs

# %%
# tokenize the outputs
# don't filter out special characters
# otherwise <sos> and <eos> won't appear
tokenizer_target = Tokenizer(num_words=MAX_NUM_WORDS,filters='')
tokenizer_target.fit_on_texts(target_texts+target_texts_inputs)
target_sequences = tokenizer_target.texts_to_sequences(target_texts)
target_sequences_inputs = tokenizer_target.texts_to_sequences(target_texts_inputs)

# %%
# get the word to index mapping for output language
word2idx_target = tokenizer_target.word_index
print('Found %s unique input tokens.' % len(word2idx_target))
# Out:
# Found 6326 unique input tokens.

# %%
# store number of output words for later
# remember to add 1 since indexing starts at 1
num_words_target = len(word2idx_target)+1

# determine maximum length output sequence
max_target_length=max(len(s) for s in target_sequences)
max_target_length
# Out:
# 9

# %% [markdown]
# ## Pad the sequences

# %%
# pad the sequences
encoder_inputs = pad_sequences(input_sequences ,maxlen=max_input_length)
print("encoder_inputs.shape:", encoder_inputs.shape)
print("encoder_inputs[0]:", encoder_inputs[0])
decoder_inputs = pad_sequences(target_sequences_inputs,maxlen=max_target_length,padding='post')
print("decoder_inputs[0]:", decoder_inputs[0])
print("decoder_inputs.shape:", decoder_inputs.shape)
decoder_targets=pad_sequences(target_sequences,maxlen=max_target_length,padding='post')
# Out:
# encoder_inputs.shape: (10000, 5)
# encoder_inputs[0]: [ 0  0  0  0 14]
# decoder_inputs[0]: [   2 1462    0    0    0    0    0    0    0]
# decoder_inputs.shape: (10000, 9)

# %% [markdown]
# ## Load pre-trained word vectors

# %%
# load in pre-trained word vectors
word2vec ={}
with open('./large_files/glove.6B/glove.6B.{}d.txt'.format(EMBEDDING_DIM)) as f:
    for line in f:
        values = line.split()
        word=values[0]
        vec = np.array(values[1:],dtype='float32')
        word2vec[word]=vec
print('Found %s word vectors.' % len(word2vec))
# Out:
# Found 400000 word vectors.

# %%
# prepare embedding matrix
num_words = min(MAX_NUM_WORDS, len(word2idx_input)+1)
embedding_matrix = np.zeros((num_words,EMBEDDING_DIM))
for word,i in word2idx_input.items():
    if i<MAX_NUM_WORDS:
        embedding_vec = word2vec.get(word)
        if embedding_vec is not None:
            embedding_matrix[i]=embedding_vec

# %%
# create embedding layer
embedding_layer = Embedding(num_words,
                            EMBEDDING_DIM,
                            weights = [embedding_matrix], 
                            input_length=max_input_length)

# %%
# create targets, since we cannot use sparse
# categorical cross entropy when we have sequences

# one-hot the targets (can't use sparse cross-entropy)
decoder_targets_one_hot = np.zeros((len(target_sequences),max_target_length,num_words_target))
for i, d in enumerate(decoder_targets):
    for t,word in enumerate(d):
        if word!=0:
            decoder_targets_one_hot[i,t,word]=1
decoder_targets_one_hot.shape
# Out:
# (10000, 9, 6327)

# %% [markdown]
# ## Build the model

# %%
encoder_input_placeholder=Input(shape = (max_input_length,))
x=embedding_layer(encoder_input_placeholder)
encoder = LSTM(LATENT_DIM,return_state=True)

encoder_outputs,h,c = encoder(x)

# keep only the states to pass into decoder
encoder_states = [h,c]

# %%
# Set up the decoder, using [h, c] as initial state.
decoder_input_placeholder=Input(shape = (max_target_length,))
# this word embedding will not use pre-trained vectors
# although you could
decoder_embedding = Embedding(num_words_target,EMBEDDING_DIM)
decoder_input_x = decoder_embedding(decoder_input_placeholder)

# since the decoder is a "to-many" model we want to have
# return_sequences=True
decoder_lstm = LSTM(LATENT_DIM,
                    return_sequences=True,
                    return_state=True)

decoder_outputs,_,_=decoder_lstm(decoder_input_x,
                                 initial_state=encoder_states)

decoder_dense = Dense(num_words_target,activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
model = Model([encoder_input_placeholder,decoder_input_placeholder],
              decoder_outputs)

# %%
import keras.backend as K
def custom_loss(y_true, y_pred):
  # both are of shape N x T x K
  mask = K.cast(y_true > 0, dtype='float32')
  out = mask * y_true * K.log(y_pred)
  return -K.sum(out) / K.sum(mask)


def acc(y_true, y_pred):
  # both are of shape N x T x K
  targ = K.argmax(y_true, axis=-1)
  pred = K.argmax(y_pred, axis=-1)
  correct = K.cast(K.equal(targ, pred), dtype='float32')

  # 0 is padding, don't include those
  mask = K.cast(K.greater(targ, 0), dtype='float32')
  n_correct = K.sum(mask * correct)
  n_total = K.sum(mask)
  return n_correct / n_total

model.compile(optimizer='adam', loss=custom_loss, metrics=[acc])

# %% [markdown]
# ## Train the model

# %%
import tensorflow as tf
tf.debugging.set_log_device_placement(True)

# %%
machines = tf.config.experimental.list_physical_devices()

# %%
tf.device(machines[-1])

# %%
# Place tensors on the CPU
r=model.fit([encoder_inputs,decoder_inputs],decoder_targets_one_hot,
         batch_size=BATCH_SIZE,
           epochs=EPOCHS,
           validation_split=0.2)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 9s 76ms/step - loss: 5.9816 - acc: 0.2763 - val_loss: 5.5082 - val_acc: 0.2689
# Epoch 2/100
# 125/125 [==============================] - 9s 71ms/step - loss: 4.9495 - acc: 0.2988 - val_loss: 5.2562 - val_acc: 0.2887
# Epoch 3/100
# 125/125 [==============================] - 9s 71ms/step - loss: 4.6065 - acc: 0.3172 - val_loss: 5.1019 - val_acc: 0.3045
# Epoch 4/100
# 125/125 [==============================] - 9s 71ms/step - loss: 4.3046 - acc: 0.3394 - val_loss: 4.9860 - val_acc: 0.3243
# Epoch 5/100
# 125/125 [==============================] - 9s 71ms/step - loss: 4.0282 - acc: 0.3635 - val_loss: 4.8602 - val_acc: 0.3521
# Epoch 6/100
# 125/125 [==============================] - 9s 71ms/step - loss: 3.7825 - acc: 0.3946 - val_loss: 4.7891 - val_acc: 0.3679
# Epoch 7/100
# 125/125 [==============================] - 9s 71ms/step - loss: 3.5526 - acc: 0.4201 - val_loss: 4.7416 - val_acc: 0.3785
# Epoch 8/100
# 125/125 [==============================] - 9s 71ms/step - loss: 3.3331 - acc: 0.4421 - val_loss: 4.6742 - val_acc: 0.3942
# Epoch 9/100
# 125/125 [==============================] - 9s 71ms/step - loss: 3.1241 - acc: 0.4628 - val_loss: 4.6643 - val_acc: 0.4053
# Epoch 10/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.9251 - acc: 0.4819 - val_loss: 4.6391 - val_acc: 0.4088
# Epoch 11/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.7386 - acc: 0.4990 - val_loss: 4.6027 - val_acc: 0.4220
# Epoch 12/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.5656 - acc: 0.5163 - val_loss: 4.5772 - val_acc: 0.4236
# Epoch 13/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.3981 - acc: 0.5335 - val_loss: 4.6210 - val_acc: 0.4222
# Epoch 14/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.2380 - acc: 0.5522 - val_loss: 4.6007 - val_acc: 0.4277
# Epoch 15/100
# 125/125 [==============================] - 9s 71ms/step - loss: 2.0855 - acc: 0.5708 - val_loss: 4.5946 - val_acc: 0.4307
# Epoch 16/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.9444 - acc: 0.5878 - val_loss: 4.5988 - val_acc: 0.4356
# Epoch 17/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.8096 - acc: 0.6085 - val_loss: 4.6142 - val_acc: 0.4303
# Epoch 18/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.6814 - acc: 0.6299 - val_loss: 4.6435 - val_acc: 0.4309
# Epoch 19/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.5632 - acc: 0.6499 - val_loss: 4.6622 - val_acc: 0.4340
# Epoch 20/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.4486 - acc: 0.6744 - val_loss: 4.6771 - val_acc: 0.4269
# Epoch 21/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.3459 - acc: 0.6921 - val_loss: 4.7141 - val_acc: 0.4291
# Epoch 22/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.2495 - acc: 0.7107 - val_loss: 4.7218 - val_acc: 0.4247
# Epoch 23/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.1597 - acc: 0.7297 - val_loss: 4.7169 - val_acc: 0.4332
# Epoch 24/100
# 125/125 [==============================] - 9s 71ms/step - loss: 1.0783 - acc: 0.7468 - val_loss: 4.7591 - val_acc: 0.4269
# Epoch 25/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.9986 - acc: 0.7637 - val_loss: 4.7625 - val_acc: 0.4341
# Epoch 26/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.9280 - acc: 0.7779 - val_loss: 4.7767 - val_acc: 0.4238
# Epoch 27/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.8615 - acc: 0.7915 - val_loss: 4.7919 - val_acc: 0.4318
# Epoch 28/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.8042 - acc: 0.8043 - val_loss: 4.8325 - val_acc: 0.4286
# Epoch 29/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.7482 - acc: 0.8161 - val_loss: 4.8570 - val_acc: 0.4281
# Epoch 30/100
# 125/125 [==============================] - 9s 70ms/step - loss: 0.6973 - acc: 0.8258 - val_loss: 4.8744 - val_acc: 0.4324
# Epoch 31/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.6536 - acc: 0.8322 - val_loss: 4.8927 - val_acc: 0.4274
# Epoch 32/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.6136 - acc: 0.8409 - val_loss: 4.8781 - val_acc: 0.4309
# Epoch 33/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.5752 - acc: 0.8466 - val_loss: 4.9315 - val_acc: 0.4297
# Epoch 34/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.5393 - acc: 0.8547 - val_loss: 4.9370 - val_acc: 0.4315
# Epoch 35/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.5104 - acc: 0.8573 - val_loss: 4.9692 - val_acc: 0.4306
# Epoch 36/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.4835 - acc: 0.8613 - val_loss: 4.9633 - val_acc: 0.4337
# Epoch 37/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.4586 - acc: 0.8646 - val_loss: 5.0109 - val_acc: 0.4302
# Epoch 38/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.4340 - acc: 0.8686 - val_loss: 5.0224 - val_acc: 0.4323
# Epoch 39/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.4151 - acc: 0.8703 - val_loss: 5.0464 - val_acc: 0.4288
# Epoch 40/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3958 - acc: 0.8740 - val_loss: 5.0608 - val_acc: 0.4330
# Epoch 41/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3802 - acc: 0.8744 - val_loss: 5.0568 - val_acc: 0.4343
# Epoch 42/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3655 - acc: 0.8773 - val_loss: 5.0831 - val_acc: 0.4302
# Epoch 43/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3506 - acc: 0.8789 - val_loss: 5.1246 - val_acc: 0.4294
# Epoch 44/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3390 - acc: 0.8801 - val_loss: 5.1574 - val_acc: 0.4310
# Epoch 45/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3277 - acc: 0.8832 - val_loss: 5.1290 - val_acc: 0.4344
# Epoch 46/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3179 - acc: 0.8835 - val_loss: 5.1635 - val_acc: 0.4304
# Epoch 47/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3076 - acc: 0.8846 - val_loss: 5.1860 - val_acc: 0.4310
# Epoch 48/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.3005 - acc: 0.8845 - val_loss: 5.1993 - val_acc: 0.4348
# Epoch 49/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2910 - acc: 0.8851 - val_loss: 5.2167 - val_acc: 0.4307
# Epoch 50/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2840 - acc: 0.8870 - val_loss: 5.2273 - val_acc: 0.4312
# Epoch 51/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2798 - acc: 0.8853 - val_loss: 5.2217 - val_acc: 0.4326
# Epoch 52/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2750 - acc: 0.8856 - val_loss: 5.2457 - val_acc: 0.4343
# Epoch 53/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2689 - acc: 0.8866 - val_loss: 5.2921 - val_acc: 0.4299
# Epoch 54/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2638 - acc: 0.8855 - val_loss: 5.2911 - val_acc: 0.4310
# Epoch 55/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2588 - acc: 0.8870 - val_loss: 5.2746 - val_acc: 0.4319
# Epoch 56/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2553 - acc: 0.8865 - val_loss: 5.3224 - val_acc: 0.4319
# Epoch 57/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2519 - acc: 0.8872 - val_loss: 5.3171 - val_acc: 0.4291
# Epoch 58/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2489 - acc: 0.8862 - val_loss: 5.3892 - val_acc: 0.4319
# Epoch 59/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2452 - acc: 0.8867 - val_loss: 5.3752 - val_acc: 0.4307
# Epoch 60/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2414 - acc: 0.8876 - val_loss: 5.4126 - val_acc: 0.4299
# Epoch 61/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2396 - acc: 0.8859 - val_loss: 5.4045 - val_acc: 0.4310
# Epoch 62/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2365 - acc: 0.8873 - val_loss: 5.4577 - val_acc: 0.4298
# Epoch 63/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2341 - acc: 0.8881 - val_loss: 5.4314 - val_acc: 0.4327
# Epoch 64/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2328 - acc: 0.8875 - val_loss: 5.4511 - val_acc: 0.4303
# Epoch 65/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2303 - acc: 0.8876 - val_loss: 5.4544 - val_acc: 0.4292
# Epoch 66/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2279 - acc: 0.8884 - val_loss: 5.4672 - val_acc: 0.4299
# Epoch 67/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2263 - acc: 0.8886 - val_loss: 5.5055 - val_acc: 0.4327
# Epoch 68/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2237 - acc: 0.8874 - val_loss: 5.5405 - val_acc: 0.4319
# Epoch 69/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2231 - acc: 0.8877 - val_loss: 5.5513 - val_acc: 0.4305
# Epoch 70/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2224 - acc: 0.8872 - val_loss: 5.5675 - val_acc: 0.4318
# Epoch 71/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2211 - acc: 0.8865 - val_loss: 5.5844 - val_acc: 0.4291
# Epoch 72/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2190 - acc: 0.8882 - val_loss: 5.5914 - val_acc: 0.4295
# Epoch 73/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2192 - acc: 0.8871 - val_loss: 5.6061 - val_acc: 0.4276
# Epoch 74/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2176 - acc: 0.8867 - val_loss: 5.6435 - val_acc: 0.4300
# Epoch 75/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2151 - acc: 0.8881 - val_loss: 5.6041 - val_acc: 0.4319
# Epoch 76/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2141 - acc: 0.8885 - val_loss: 5.6397 - val_acc: 0.4288
# Epoch 77/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2134 - acc: 0.8881 - val_loss: 5.6222 - val_acc: 0.4299
# Epoch 78/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2134 - acc: 0.8881 - val_loss: 5.6853 - val_acc: 0.4284
# Epoch 79/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2122 - acc: 0.8869 - val_loss: 5.6681 - val_acc: 0.4332
# Epoch 80/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2116 - acc: 0.8859 - val_loss: 5.7093 - val_acc: 0.4283
# Epoch 81/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2097 - acc: 0.8875 - val_loss: 5.7500 - val_acc: 0.4253
# Epoch 82/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2094 - acc: 0.8869 - val_loss: 5.7414 - val_acc: 0.4275
# Epoch 83/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2089 - acc: 0.8876 - val_loss: 5.7497 - val_acc: 0.4281
# Epoch 84/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2079 - acc: 0.8886 - val_loss: 5.7873 - val_acc: 0.4250
# Epoch 85/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2069 - acc: 0.8882 - val_loss: 5.7473 - val_acc: 0.4326
# Epoch 86/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2064 - acc: 0.8873 - val_loss: 5.7992 - val_acc: 0.4289
# Epoch 87/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2054 - acc: 0.8876 - val_loss: 5.8416 - val_acc: 0.4282
# Epoch 88/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2046 - acc: 0.8875 - val_loss: 5.8178 - val_acc: 0.4288
# Epoch 89/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2023 - acc: 0.8892 - val_loss: 5.8108 - val_acc: 0.4297
# Epoch 90/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2034 - acc: 0.8870 - val_loss: 5.8677 - val_acc: 0.4294
# Epoch 91/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2023 - acc: 0.8870 - val_loss: 5.8556 - val_acc: 0.4306
# Epoch 92/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2020 - acc: 0.8885 - val_loss: 5.8491 - val_acc: 0.4295
# Epoch 93/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2018 - acc: 0.8877 - val_loss: 5.8467 - val_acc: 0.4289
# Epoch 94/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2017 - acc: 0.8879 - val_loss: 5.8748 - val_acc: 0.4286
# Epoch 95/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2019 - acc: 0.8873 - val_loss: 5.9001 - val_acc: 0.4277
# Epoch 96/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2003 - acc: 0.8881 - val_loss: 5.8796 - val_acc: 0.4316
# Epoch 97/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.1993 - acc: 0.8878 - val_loss: 5.9175 - val_acc: 0.4271
# Epoch 98/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.2001 - acc: 0.8880 - val_loss: 5.9347 - val_acc: 0.4242
# Epoch 99/100
# 125/125 [==============================] - 9s 71ms/step - loss: 0.1988 - acc: 0.8875 - val_loss: 6.0008 - val_acc: 0.4250
# Epoch 100/100
# 125/125 [==============================] - 9s 70ms/step - loss: 0.1979 - acc: 0.8868 - val_loss: 5.9714 - val_acc: 0.4249

# %% [markdown]
# ## Plot

# %%
# plot some data
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# accuracies
plt.plot(r.history['acc'], label='acc')
plt.plot(r.history['val_acc'], label='val_acc')
plt.legend()
plt.show()

# %% [markdown]
# ## Make predictions

# %%
##### Make predictions #####
# As with the poetry example, we need to create another model
# that can take in the RNN state and previous word as input
# and accept a T=1 sequence.

# The encoder will be stand-alone
# From this we will get our initial decoder hidden state
# Create encoder model - takes in English sentences and return the final LSTM h&c
encoder_model = Model(encoder_input_placeholder,encoder_states)

# %%
# Create decoder model - use existing layers

# initial h & c for the LSTM
decoder_state_input_h = Input(shape=(LATENT_DIM,))
decoder_state_input_c = Input(shape=(LATENT_DIM,))
decoder_state_inputs = [decoder_state_input_h,decoder_state_input_c]

# %%
# a new input into the embedding
# shape = (1,) since we generate 1 word as a time
decoder_input_single = Input(shape=(1,))
decoder_input_single_x =decoder_embedding(decoder_input_single)

# %%
decoder_outputs,h,c = decoder_lstm(decoder_input_single_x,initial_state=decoder_state_inputs)
decoder_states=[h,c]
decoder_outputs = decoder_dense(decoder_outputs)

# The sampling model
# inputs: y(t-1), h(t-1), c(t-1)
# outputs: y(t), h(t), c(t)
decoder_model=Model([decoder_input_single]+decoder_state_inputs, [decoder_outputs]+decoder_states)

# %%
idx2word_eng={v:k for k, v in word2idx_input.items()}
idx2word_trans = {v:k for k,v in word2idx_target.items()}

# %%
# takes in an input sentence and generate a translation
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    state_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    # 1 sample and 1 timestamp
    target_seq= np.zeros((1,1))
    # Populate the first character of target sequence with the start character.
    # NOTE: tokenizer lower-cases all words
    target_seq[0,0]=word2idx_target.get('<sos>')

    # if we get this we break
    eos = word2idx_target.get('<eos>')

    # Create the translation
    output_translation =[]
    for _ in range(max_target_length):
        output_tokens,h,c = decoder_model.predict([target_seq]+state_value)

        # Get next word
        idx = np.argmax(output_tokens[0,0,:])
        if idx == eos:
            print(idx)
            break
        word = ''
        if idx>0:
            word = idx2word_trans[idx]
            output_translation.append(word)
        # Update the decoder input
        # which is just the word just generated
        target_seq[0,0] = idx

        # Update states
        state_value=[h,c]
    return ' '.join(output_translation)

# %%
i = np.random.choice(len(input_texts))
input_seq = encoder_inputs[i:i+1]
translation = decode_sequence(input_seq)
print('-')
print('Input:', input_texts[i])
print('Translation:', translation)
# Out:
# 1
# -
# Input: I love fish.
# Translation: me encanta el pescado.
